# %%
# !python --version

# %%
# !pip --version

# %%
import shutil
assert shutil.which("sciunit") is not None, "Sciunit not installed"
print("Sciunit is available")

# %% [markdown]
# Only run the below cell if sciunit is not installed already

# %%
# !pip install --user sciunit2
